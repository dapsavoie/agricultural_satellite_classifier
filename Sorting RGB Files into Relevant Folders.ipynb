# %% [markdown]
# # Load packages and data

# %%
from tqdm import tqdm

# %%
import os 
import pandas as pd 
from keras.preprocessing.image import ImageDataGenerator, load_img
# example of loading an image with the Keras API
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import array_to_img
from keras.preprocessing import image


from keras.layers import MaxPooling2D

# %%
BASE_DIR ='D:/agriculture_computer_vision/Agriculture-Vision/'
train_folder = BASE_DIR + 'train/labels/'
train_cloud_shadow = BASE_DIR + 'train/labels/cloud_shadow/'
train_double_plant = BASE_DIR + 'train/labels/double_plant/'
train_planter_skip = BASE_DIR + 'train/labels/planter_skip/'
train_standing_water = BASE_DIR + 'train/labels/standing_water/'
train_water_way = BASE_DIR + 'train/labels/waterway/'
train_weed_cluster = BASE_DIR + 'train/labels/weed_cluster/'

rgb = os.path.join(BASE_DIR, 'train/images/rgb/')

test_folder_boundaries = os.path.join(BASE_DIR,'test/boundaries/')

val_folder = os.path.join(BASE_DIR, 'val/boundaries/')

# %%
final_encoded = pd.read_csv(r'C:\Users\User\Desktop\agri_vision\final_encoded.csv')

# %%
final_encoded.drop(columns= 'Unnamed: 0', inplace=True)

# %%
final_encoded['index'] = final_encoded['index'].str.rstrip('.png')

# %% [markdown]
# # Helper Functions

# %%
#creates a list of files based on one-hot encoded file


def sort_folder_into_classes(encoded_df, column_name, list_name):
    
    
    list_name = encoded_df.loc[encoded_df[column_name] == 1] #select columns you want to move
    list_name['index'] = list_name['index'].astype(str) + '.jpg' #make sure the .jpg lines up as original files are png but directory we are matching is jpeg

    identifier_list = [] #create am empty list for the identiies

    identifier_list = list_name['index'] #create a list of relevant image names
    identifier_list.append(identifier_list) #append to empty list
    unique_identifiers = set(identifier_list) #transform to a set 

    return unique_identifiers

# %%
# move folders 


def move_unique_id_to_folder(mypath, unique_identifier_set):

#path to image folder is specified in argument
# onlyfiles stores it in a list

    onlyfiles = [f for f in os.listdir(mypath) if os.path.isfile(os.path.join(mypath, f))]

    #ls1 is a list of unique identifiers generated by the previous function
    ls1 = unique_identifiers

    #list of image names
    ls1files = [i for i in onlyfiles for j in ls1 if j in i]

    subfolder1 = os.path.join(mypath, 'new_folder_name'')

    # check if they already exits to prevent error
    if not os.path.exists(subfolder1):
    os.makedirs(subfolder1)

    # move files to their respective sub folders
    for i in ls1files:
    source = os.path.join(mypath, i)
    destination = os.path.join(subfolder1, i)
    os.rename(source, destination)
    
    return print('Check Destination folder to see your newly sorted files!')

# %% [markdown]
# # Manual Data Cleaning

# %%
cloud_shadow = final_encoded.loc[final_encoded['cloud_shadow'] == 1]
cloud_shadow
# Out:
#                                   index  cloud_shadow  double_planter  \
# 201        1DJX4RH9N_1609-506-2121-1018             1               0
# 202        1DJX4RH9N_1792-892-2304-1404             1               0
# 203        1DJX4RH9N_2121-506-2633-1018             1               0
# 204        1DJX4RH9N_2304-892-2816-1404             1               0
# 205         1DJX4RH9N_2816-380-3328-892             1               0
# ...                                 ...           ...             ...
# 12896  ZYI6ZLYNH_9545-12379-10057-12891             1               0
# 12897   ZYI6ZLYNH_9545-9819-10057-10331             1               0
# 12898    ZYI6ZLYNH_9556-3534-10068-4046             1               0
# 12899  ZYI6ZLYNH_9952-10044-10464-10556             1               0
# 12900    ZYI6ZLYNH_9952-6460-10464-6972             1               0
#
#        planter_skip  standing_water  waterway  weed_cluster
# 201               0               0         0             0
# ...

# %%
cloud_shadow['index'] = cloud_shadow['index'].astype(str) + '.jpg'
loud_list = []
cloud_list = cloud_shadow['index']
cloud_list.append(cloud_list)
unique_identifiers = set(cloud_list)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
cloud_shadow['index'] = cloud_shadow['index'].astype(str) + '.jpg'
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
import os 

#path to image folder
mypath = 'D:/agriculture_computer_vision/Agriculture-Vision/train/images/rgb_copy/'

onlyfiles = [f for f in os.listdir(mypath) if os.path.isfile(os.path.join(mypath, f))]

ls1 = unique_identifiers

#list of image names
ls1files = [i for i in onlyfiles for j in ls1 if j in i]


subfolder1 = os.path.join(mypath, 'ls1')


# check if they already exits to prevent error
if not os.path.exists(subfolder1):
    os.makedirs(subfolder1)

    # move files to their respective sub folders
for i in ls1files:
    source = os.path.join(mypath, i)
    destination = os.path.join(subfolder1, i)
    os.rename(source, destination)

# %%
#double planter 

double_planter = final_encoded.loc[final_encoded['double_planter'] == 1]

double_planter['index'] = double_planter['index'].astype(str) + '.jpg'
double_planter_list = []
double_planter_list = double_planter['index']
double_planter_list.append(double_planter_list)
unique_identifiers = set(double_planter_list)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
import os 

#path to image folder
mypath = 'D:/agriculture_computer_vision/Agriculture-Vision/train/images/rgb_copy/'

onlyfiles = [f for f in os.listdir(mypath) if os.path.isfile(os.path.join(mypath, f))]

ls1 = unique_identifiers

#list of image names
ls1files = [i for i in onlyfiles for j in ls1 if j in i]


subfolder1 = os.path.join(mypath, 'ls1')


# check if they already exits to prevent error
if not os.path.exists(subfolder1):
    os.makedirs(subfolder1)

    # move files to their respective sub folders
for i in ls1files:
    source = os.path.join(mypath, i)
    destination = os.path.join(subfolder1, i)
    os.rename(source, destination)

# %%
#planter skip

planter_skip = final_encoded.loc[final_encoded['planter_skip'] == 1]
planter_skip['index'] = planter_skip['index'].astype(str) + '.jpg'

planter_skip_list = []

planter_skip_list = planter_skip['index']
planter_skip_list.append(planter_skip_list)
unique_identifiers = set(planter_skip_list)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
import os 

#path to image folder
mypath = 'D:/agriculture_computer_vision/Agriculture-Vision/train/images/rgb_copy/'

onlyfiles = [f for f in os.listdir(mypath) if os.path.isfile(os.path.join(mypath, f))]

ls1 = unique_identifiers

#list of image names
ls1files = [i for i in onlyfiles for j in ls1 if j in i]


subfolder1 = os.path.join(mypath, 'ls1')


# check if they already exits to prevent error
if not os.path.exists(subfolder1):
    os.makedirs(subfolder1)

    # move files to their respective sub folders
for i in ls1files:
    source = os.path.join(mypath, i)
    destination = os.path.join(subfolder1, i)
    os.rename(source, destination)

# %%
#standing_water
standing_water = final_encoded.loc[final_encoded['standing_water'] == 1]
standing_water['index'] = standing_water['index'].astype(str) + '.jpg'

standing_water_list = []

standing_water_list = standing_water['index']
standing_water_list.append(standing_water_list)
unique_identifiers = set(standing_water_list)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import os 

#path to image folder
mypath = 'D:/agriculture_computer_vision/Agriculture-Vision/train/images/rgb_copy/'

onlyfiles = [f for f in os.listdir(mypath) if os.path.isfile(os.path.join(mypath, f))]

ls1 = unique_identifiers

#list of image names
ls1files = [i for i in onlyfiles for j in ls1 if j in i]


subfolder1 = os.path.join(mypath, 'standing_water')


# check if they already exits to prevent error
if not os.path.exists(subfolder1):
    os.makedirs(subfolder1)

    # move files to their respective sub folders
for i in ls1files:
    source = os.path.join(mypath, i)
    destination = os.path.join(subfolder1, i)
    os.rename(source, destination)

# %%
#waterway
waterway = final_encoded.loc[final_encoded['waterway'] == 1]
waterway['index'] = waterway['index'].astype(str) + '.jpg'

waterway_list = []

waterway_list = waterway['index']
waterway_list.append(waterway_list)
unique_identifiers = set(waterway_list)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#path to image folder
mypath = 'D:/agriculture_computer_vision/Agriculture-Vision/train/images/rgb_copy/'

onlyfiles = [f for f in os.listdir(mypath) if os.path.isfile(os.path.join(mypath, f))]

ls1 = unique_identifiers

#list of image names
ls1files = [i for i in onlyfiles for j in ls1 if j in i]


subfolder1 = os.path.join(mypath, 'waterway')


# check if they already exits to prevent error
if not os.path.exists(subfolder1):
    os.makedirs(subfolder1)

    # move files to their respective sub folders
for i in ls1files:
    source = os.path.join(mypath, i)
    destination = os.path.join(subfolder1, i)
    os.rename(source, destination)

# %%
#weed cluster

weed_cluster = final_encoded.loc[final_encoded['weed_cluster'] == 1]
weed_cluster['index'] = weed_cluster['index'].astype(str) + '.jpg'

weed_cluster_list = []

weed_cluster_list = weed_cluster['index']
weed_cluster_list.append(weed_cluster_list)
unique_identifiers = set(weed_cluster_list)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#path to image folder
mypath = 'D:/agriculture_computer_vision/Agriculture-Vision/train/images/rgb_copy/'

onlyfiles = [f for f in os.listdir(mypath) if os.path.isfile(os.path.join(mypath, f))]

ls1 = unique_identifiers

#list of image names
ls1files = [i for i in onlyfiles for j in ls1 if j in i]


subfolder1 = os.path.join(mypath, 'weed_cluster')


# check if they already exits to prevent error
if not os.path.exists(subfolder1):
    os.makedirs(subfolder1)

    # move files to their respective sub folders
for i in ls1files:
    source = os.path.join(mypath, i)
    destination = os.path.join(subfolder1, i)
    os.rename(source, destination)
